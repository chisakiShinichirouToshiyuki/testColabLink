# %%
# !git clone https://github.com/chisakiShinichirouToshiyuki/testColabLink.git

# %%
# !pip install sympy
# !pip install pyarmor

# %%
from testColabLink.dist_byColab.base import Base as b

b().calc()
# Out:
# Could not find "/Users/kizakiyasushiei/Desktop/testColabLink/dist_byColab/pytransform/platforms/darwin/x86_64/_pytransform.dylib"
# ---------------------------------------------------------------------------
# PytransformError                          Traceback (most recent call last)
# File ~/Desktop/testColabLink/dist_byColab/pytransform/__init__.py:364, in pyarmor_runtime(path, suffix, advanced)
#     363 try:
# --> 364     pyarmor_init(path, is_runtime=1, suffix=suffix, advanced=advanced)
#     365     init_runtime()
#
# File ~/Desktop/testColabLink/dist_byColab/pytransform/__init__.py:355, in pyarmor_init(path, is_runtime, platid, suffix, advanced)
#     354 global _pytransform
# --> 355 _pytransform = _load_library(path, is_runtime, platid, suffix, advanced)
#     356 return init_pytransform()
#
# File ~/Desktop/testColabLink/dist_byColab/pytransform/__init__.py:317, in _load_library(path, is_runtime, platid, suffix, advanced)
#     316 if not os.path.exists(filename):
# ...
